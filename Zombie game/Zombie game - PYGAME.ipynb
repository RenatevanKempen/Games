# %%
import pygame
import os
import time

pygame.init()

#red = (181,55,55)
red = (255,0,0)
green = (0,255,0)
blue = (0,0,255)
darkBlue = (0,0,128)
white = (255,255,255)
black = (0,0,0)
pink = (255,200,200)

display_width = 1200
display_height = 1000

zombie_width = 106

pygame.display.set_caption("Zombie Slayer Game")
clock = pygame.time.Clock()

gameDisplay = pygame.display.set_mode((display_width, display_height))

_image_library = {}
def get_image(path):
        global _image_library
        image = _image_library.get(path)
        if image == None:
                canonicalized_path = path.replace('/', os.sep).replace('\\', os.sep)
                image = pygame.image.load(canonicalized_path)
                _image_library[path] = image
        return image

def zombie(x,y):
    gameDisplay.blit(get_image('zombie.png'), (x, y))
    pygame.draw.rect(gameDisplay, black ,(400,400,400,200), 10)
    #pygame.draw.circle(gameDisplay, , pos, radius, width=50)
    #pygame.draw.lines(gameDisplay, pink, False,  [(100,100), (150,200), (200,100)], 10)

def text_objects(text, font):
    textSurface = font.render(text, True, red)
    return textSurface, textSurface.get_rect()
        
def message_display(text):
    largeText = pygame.font.Font('freesansbold.ttf', 55)
    TextSurf, TextRect = text_objects(text, largeText)
    TextRect.center = ((display_width/2), (display_height/2))
    gameDisplay.blit(TextSurf, TextRect)
    
    pygame.display.update()
    
    time.sleep(2)
    
    game_loop()
        
def zombie_talk():
    message_display("WHOHAHA, ARRGHHH... BRAINS...")
    
def game_loop():
             
    x = (display_width * 0.45)
    y = (display_height * 0.8)

    gameExit = False
    
    x_change = 0
    y_change = 0
    
    

    while not gameExit:
            for event in pygame.event.get():
                    if event.type == pygame.QUIT:
                            gameExit = True

                    if event.type == pygame.KEYDOWN:
                        if event.key == pygame.K_LEFT:
                            x_change = -5
                        elif event.key == pygame.K_RIGHT:
                            x_change = 5
                           # y_change = 2

                    if event.type == pygame.KEYUP:
                        if event.key == pygame.K_LEFT or event.key == pygame.K_RIGHT:
                            x_change = 0
                           # y_change = -2

            x += x_change
            #y += y_change

            gameDisplay.fill(white)
            zombie(x,y)

            pygame.display.update()
            
            if x > display_width - zombie_width or x < 0:
                zombie_talk()
            
            #pygame.display.flip()
            clock.tick(60)

game_loop()            
pygame.quit()  
quit()
# Out:
# pygame 1.9.6
# Hello from the pygame community. https://www.pygame.org/contribute.html
